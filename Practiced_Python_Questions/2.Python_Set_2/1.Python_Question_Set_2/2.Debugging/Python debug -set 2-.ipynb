# %%
#1.Find the error in the following Python code:
import math
print=print(math.sqrt(16))

#Error is math case instead Math to math
#Predefined funtion on math so case senstive issue
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    
    x += 5
    print(x)
    
x = 10
my_function()
#Memory issue so Restart the Kernal and run the function
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 7
#       4     print(x)
#       6 x = 10
# ----> 7 my_function()
#       8 #Memory issue so Restart the Kernal and run the function
#
# Cell In[9], line 3, in my_function()
#       2 def my_function():
# ----> 3     x += 5
#       4     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
#2.Find the error in the following Python code:
def my_function():
    global y
    print
    y += 5 #x=x+5
    print(x)
    
y= 10
my_function()
#Memory issue so Restart the Kernal and run the function
# Out:
# 15

# %%
#3.y = 10
y=10
if y == 10:
    print("y is 10")
# Out:
# y is 10

# %%
#4.
#numbers = [5, 3, 8, 2]
#print(numbers.sort())

#numbers = [5, 3, 8, 2]
#numbers.sort()  # Modifies the list in-place
#Print(numbers)  # Output: [2, 3, 5, 8]

a = [5, 3, 8, 2]
a.sort(reverse=True)
print(a)

#a.sort(reverse=True)   Reverse keyword is not defined so it has been thowed the Error
# Out:
# [8, 5, 3, 2]

# %%
#5.

def square(n):
    n * n
    print(square(4))
#Value not pass into the function

# %%
#6.tuples store multiple value into single variable
tup = (1, 2, 3)
print("Value in tup[0] = ", tup[0])
print("Value in tup[1] = ", tup[1])
print("Value in tup[2] = ", tup[2])
# Out:
# Value in tup[0] =  1
# Value in tup[1] =  2
# Value in tup[2] =  3

# %%
#7.declare the age variable missing in the (())
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1,1):
    print(i)

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
