# %%
print("Welcome to Hope Ai")
# Out:
# Welcome to Hope Ai

# %%
Print statement with variable
# Out:
#   Cell In[7], line 1
#     Print statement with variable
#           ^
# SyntaxError: invalid syntax

# %%
fee=10
print("hope AI Course fees:",fee)
# Out:
# hope AI Course fees: 10

# %%
print("The addtion and subtraction of two number")
addnumber1=50
addnumber2=50
add = addnumber1 + addnumber2
subtraction = addnumber1 - addnumber2

print("The addition number1:",add)
print("The subtraction number:",subtraction)
# Out:
# The addtion and subtraction of two number
# The addition number1: 100
# The subtraction number: 0

# %%
age=13
if(age==13):
    print("Adult")
else:
    print("Nil")
# Out:
# Adult

# %%
name="Madhu"
print("Enter your name:",name)
print("Enter your age:",35);print("Enter your school name: Guru school") 
print("Enter your drgree: B.E CSE")
# Out:
# Enter your name: Madhu
# Enter your age: 35
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
addnumber1=43
addnumber2=34
add = addnumber1 + addnumber2
print("The add =",add)
# Out:
# The add = 77

# %%
subnumber1=43
subnumber2=34
sub = subnumber1 - subnumber2
print("The sub =",sub)
# Out:
# The sub = 9

# %%
multiplenum1=63
multiplenum2=97
Multiple = multiplenum1 * multiplenum2
print("The Mul =",Multiple)
# Out:
# The Mul = 6111

# %%
divnumber1=76
divnumber2=31
division = divnumber1 / divnumber2
print("The division =",division)
# Out:
# The division = 2.4516129032258065

# %%
divnumber1=76
divnumber2=31
divnumber = divnumber1 // divnumber2
print("The division =",divnumber)
# Out:
# The division = 2

# %%
Modulo1=4
Modulo2=4
Moduloresult = pow(Modulo1, Modulo2)
print("The Modulo =",Moduloresult)
# Out:
# The Modulo = 256
